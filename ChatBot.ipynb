# %%
import numpy as np
import string
from nltk.corpus import stopwords
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction.text import TfidfTransformer,TfidfVectorizer
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv('/content/dialogs.txt',sep='\t')
df
# Out:
#                                               Questions  \
# 0                                hi, how are you doing?
# 1                         i'm fine. how about yourself?
# 2                   i'm pretty good. thanks for asking.
# 3                     no problem. so how have you been?
# 4                      i've been great. what about you?
# ...                                                 ...
# 3720    that's a good question. maybe it's not old age.
# 3721                              are you right-handed?
# 3722                                  yes. all my life.
# 3723  you're wearing out your right hand. stop using...
# 3724        but i do all my writing with my right hand.
#
#                                                 Answers
# 0                         i'm fine. how about yourself?
# 1                   i'm pretty good. thanks for asking.
# 2                     no problem. so how have you been?
# 3                      i've been great. what about you?
# ...

# %%
a = pd.Series(df.columns)

# %%
b = {"Questions":['hi','Hello','how are you','how are you doing'],
     "Answers":['hello','hi',"i'm fine. how about yourself?","i'm fine. how about yourself?"]}
b = pd.DataFrame(b)

# %%
df = pd.concat([df,b])
df
# Out:
#                                         Questions  \
# 0                          hi, how are you doing?
# 1                   i'm fine. how about yourself?
# 2             i'm pretty good. thanks for asking.
# 3               no problem. so how have you been?
# 4                i've been great. what about you?
# ...                                           ...
# 3724  but i do all my writing with my right hand.
# 0                                              hi
# 1                                           Hello
# 2                                     how are you
# 3                               how are you doing
#
#                                                 Answers
# 0                         i'm fine. how about yourself?
# 1                   i'm pretty good. thanks for asking.
# 2                     no problem. so how have you been?
# 3                      i've been great. what about you?
# 4              i've been good. i'm in school right now.
# ...

# %%
df
# Out:
#                                         Questions  \
# 0                          hi, how are you doing?
# 1                   i'm fine. how about yourself?
# 2             i'm pretty good. thanks for asking.
# 3               no problem. so how have you been?
# 4                i've been great. what about you?
# ...                                           ...
# 3724  but i do all my writing with my right hand.
# 0                                              hi
# 1                                           Hello
# 2                                     how are you
# 3                               how are you doing
#
#                                                 Answers
# 0                         i'm fine. how about yourself?
# 1                   i'm pretty good. thanks for asking.
# 2                     no problem. so how have you been?
# 3                      i've been great. what about you?
# 4              i've been good. i'm in school right now.
# ...

# %%
def cleaner(x):
    return [a for a in (''.join([a for a in x if a not in string.punctuation])).lower().split()]

# %%
Pipe = Pipeline([
    ('bow',CountVectorizer(analyzer=cleaner)),
    ('tfidf',TfidfTransformer()),
    ('classifier',DecisionTreeClassifier())
])

# %%
Pipe.fit(df['Questions'],df['Answers'])
# Out:
# Pipeline(steps=[('bow',
#                  CountVectorizer(analyzer=<function cleaner at 0x7e5859b3c430>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('classifier', DecisionTreeClassifier())])

# %%
Pipe.predict(['hi'])[0]
# Out:
# 'hello'

# %%
Pipe.predict(['how are you'])[0]
# Out:
# "i'm fine. how about yourself?"

# %%
Pipe.predict(['great'])[0]
# Out:
# 'i appreciate that.'

# %%
Pipe.predict(['What are you doing'])[0]
# Out:
# "i'm going to change the light bulb. it burnt out."
